# %% [markdown]
# <center><font size="+4">Programming & Data Analytics & AI 1 2022/2023</font></center>
# <center><font size="+2">Sant'Anna School of Advanced Studies, Pisa, Italy</font></center>
# <center><img src="https://github.com/EMbeDS-education/StatsAndComputing20212022/raw/main/PDA/jupyter/jupyterNotebooks/images/SSSA.png" width="700" alt="EMbeDS"></center>
#
# <center><font size="+2">Course responsible</font></center>
# <center><font size="+2">Andrea Vandin a.vandin@santannapisa.it</font></center>
#
# <center><font size="+2">Co-lecturer (informally)</font></center>
# <center><font size="+2">Daniele Licari d.licari@santannapisa.it</font></center>
#
# <center><font size="+2">Teaching Assistant</font></center>
# <center><font size="+2">Sima Sarv Ahrabi Sima.SarvAhrabi@santannapisa.it</font></center>
#
# ---

# %% [markdown]
# <center><font size="+4">Lecture 5: </font></center>
# <center><font size="+2"> Creation of word clouds for COVID-related online news</font></center>
# </center>

# %% [markdown]
# ---

# %%
from IPython.display import Image, display
url_github_repo="https://github.com/EMbeDS-education/StatsAndComputing20222023/raw/main/PDAI/"
img=Image(url_github_repo+'slides/figures/calendarPDAI1.png',width=800)
display(img)

# %% [markdown]
# # Computing and visulatizing the most important words in online news

# %% [markdown]
# This example shows that functions can hide a lot of complexity.
# * E.g., we can download remote data by just invoking a function
# * In particular, in this example we will:
#     1. Download all the articles from the online service [NewsAPI](https://newsapi.org/)
#          - An online service is like a function running on the internet...
#     2. Combine the articles into one document (`str`)
#     3. Clean data
#     4. Compute word-frequency pairs
#         - Word 'ciao' appears 3 times, word 'hello' appears 6 times ...
#     5. Visualize the analysis in a Word Cloud

# %% [markdown]
# *Some definitions:*

# %% [raw]
# ![](images/web_server_web_service.png)

# %%
from IPython.display import Image, display
url_github_repo="https://github.com/EMbeDS-education/StatsAndComputing20222023/raw/main/PDAI/"
img=Image(url_github_repo+'jupyter/jupyterNotebooks/images/web_server_web_service.png',width=800)
display(img)

# %% [markdown]
# A **web service** is an application run by a web server (a remote computer connected to the interent).
# - The service can be called/invoked from some other computers connected to the internet
# - The service will _return_ data in a format that can't be sent over the internet
#   - A little bit like a webpage, which is loaded from some remote server, and visualized in a browser
#   - However, here data is not visualized but sent in a format that can be processed by programs.
#   - Examples of used formats are XML (especially SOAP or so) or JSON.
#
# An **Application Programming Interface (API)** allows two programs to communicate with one another.
# - An API defines the functions for one software program to interact with the other.

# %% [markdown]
# This document has been __created by Daniele Licari__ and elaborated by Andrea Vandin.

# %% [markdown]
# # The modules we need to use

# %%
# %pip install newsapi-python
# %pip install wordcloud
# Out:
# Collecting newsapi-python
#   Downloading newsapi_python-0.2.6-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: requests<3.0.0 in /Users/andrea/Documents/python_envs/env_pda_2022/lib/python3.9/site-packages (from newsapi-python) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/andrea/Documents/python_envs/env_pda_2022/lib/python3.9/site-packages (from requests<3.0.0->newsapi-python) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/andrea/Documents/python_envs/env_pda_2022/lib/python3.9/site-packages (from requests<3.0.0->newsapi-python) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/andrea/Documents/python_envs/env_pda_2022/lib/python3.9/site-packages (from requests<3.0.0->newsapi-python) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/andrea/Documents/python_envs/env_pda_2022/lib/python3.9/site-packages (from requests<3.0.0->newsapi-python) (3.3)
# Installing collected packages: newsapi-python
# Successfully installed newsapi-python-0.2.6
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/andrea/Documents/python_envs/env_pda_2022/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-macosx_10_9_x86_64.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 KB 808.6 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pillow in /Users/andrea/Documents/python_envs/env_pda_2022/lib/python3.9/site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: matplotlib in /Users/andrea/Documents/python_envs/env_pda_2022/lib/python3.9/site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: numpy>=1.6.1 in /Users/andrea/Documents/python_envs/env_pda_2022/lib/python3.9/site-packages (from wordcloud) (1.22.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/andrea/Documents/python_envs/env_pda_2022/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/andrea/Documents/python_envs/env_pda_2022/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/andrea/Documents/python_envs/env_pda_2022/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/andrea/Documents/python_envs/env_pda_2022/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /Users/andrea/Documents/python_envs/env_pda_2022/lib/python3.9/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/andrea/Documents/python_envs/env_pda_2022/lib/python3.9/site-packages (from matplotlib->wordcloud) (4.29.1)
# Requirement already satisfied: six>=1.5 in /Users/andrea/Documents/python_envs/env_pda_2022/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/andrea/Documents/python_envs/env_pda_2022/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# integrating News API into your Python application 
from newsapi import NewsApiClient 

# creating wordclouds into your Python application 
from wordcloud import WordCloud, STOPWORDS

#  In Python, string.punctuation will give the sets of all punctuations. 
import string

import matplotlib.pyplot as plt

# %% [markdown]
# __NewsApiClient__ is a local client for the online service [__NewsAPI__](https://newsapi.org/) that allows you to get news from [eveywhere in the world](https://newsapi.org/sources)
# * Intuitively, an online service is like an online function running in a remote server (computer)
# * A local client is a piece of code runnning in your machine that communicates with the online service
#   * It allows you to easily interact with the online service
#   * The interaction is typically done through a set of message exchanges as prescribed by the APIs of the service
# * We need a `api_key` that is a univoque identifier
#   * necessary when making requests to be identified
#   * __can be obtained registering [here](https://newsapi.org/register)__

# %% [markdown]
# There exist many online services accessible with Python (e.g. [Twitter API](https://www.tweepy.org/))
# * Most of them follow this api-key approach
# * E.g. to enforce subscriptions
# <!-- * In our case, __we are using a free subscription that allows us to only get the first 250 characters from a news item__ -->

# %% [markdown]
# # Data loading

# %% [markdown]
# We first get the most relevant articles (top 100) about coronavirus, published in usa-today
# * This looks like a [normal function invocation](https://newsapi.org/docs/client-libraries/python)
# * But under the hood a lot happens to contact the remote service
# (https://newsapi.org/v2/everything?q=coronavirus&sources=usa-today&language=en&pageSize=100&sortBy=relevancy&apiKey=1f6979fc955b465f9b076310217a19a3)
#
# Luckily, the function `get_everything` hides this complexity to us

# %%
my_api_key='1f6979fc955b465f9b076310217a19a3'
#newsapi = NewsApiClient(api_key='345f8a0aa8c64d549fde1d8343d036f8')
newsapi = NewsApiClient(api_key=my_api_key)
json_data = newsapi.get_everything(q='coronavirus',        # All the articles that contain this word
                                    language='en',
                                    sources = 'usa-today', # The newspaper of interest
                                    #sources = 'cnn', # The newspaper of interest
                                    #sources = 'bbc-news', # The newspaper of interest
                                    #sources = 'bbc-news,the-verge'
                                    #
                                    page_size=100,           # Get 100 articles
                                    sort_by='relevancy',
                                    
                                   
                                    )
#There exist many more parameters allowing us the ask for more articles, different sources, etc

# %% [markdown]
# The return value `json_data` is just a dictionary collecting information about the remote request

# %%
print(type(json_data))
print()
print(json_data.keys())
print()
print('The status of the request is',json_data['status'],'There are ',json_data['totalResults'],'articles matching the request.')
print('We got',len(json_data['articles']),'articles')
print()
# Out:
# <class 'dict'>
#
# dict_keys(['status', 'totalResults', 'articles'])
#
# The status of the request is ok There are  24 articles matching the request.
# We got 24 articles

# %% [markdown]
# We can ignore all the metadata (i.e. the data about the remote request) and focus on the actual articles only

# %%
articles = json_data['articles'] 

#Get the description of the first article
content = articles[0]['description']
print('The content:')
print(content)
print('The content is long',len(content),"characters")
# Out:
# The content:
# XBB.1.5 makes up more than 40% of cases, the CDC says. While it's more contagious, experts say it seems not to be more dangerous than earlier ones.
# The content is long 147 characters

# %% [markdown]
# Now let's combine the content of all the news into variable `contents`

# %%
def combine_articles(list_of_articles):
    contents = ''
    for article in list_of_articles:
         #  check if key 'description' has Non-None value in dictionary 
        if article['description']:
            contents += article['description']+" "
            
    return contents

contents = combine_articles(articles)
print('Overall we have',len(contents),'characters')
# Out:
# Overall we have 3295 characters

# %% [markdown]
# # Data cleaning, manipulation and visualization

# %% [markdown]
# ## Implementing two functions for data cleaning

# %% [markdown]
# __Stop words__ are usually the most common words in any text ( like “the”, “of”, “to” and “and”),
# * They don’t tell us much about the actual content in a text
# * These are the words we want to ignore - this is our data cleaning
#
# We want to find the words that will help us differentiate a text from texts that are about different subjects.
# * __We will filter out the common words__.
# * Of course, we are going to use a function for doing this

# %% [markdown]
# Furthermore, we want to ignore punctuation
# * In Python, string.punctuation will give the all sets of punctuation.
# * We are going to use it to delete all punctuation from a string

# %%
# to remove STOPWORDS from a list of strings
def remove_stopwords(wordlist):
    return [w for w in wordlist if w not in STOPWORDS]

# to remove Punctuations from a string
def remove_punctuations(my_str): 
    no_punct = ""
    for char in my_str:
        if char  not in string.punctuation:
            no_punct = no_punct + char
    return no_punct

# for testing 
remove_stopwords(remove_punctuations('Andrea likes pizza and Python!! and you?').split())
# Out:
# ['Andrea', 'likes', 'pizza', 'Python']

# %% [markdown]
# ## Actual cleaning, manipulation, visualization

# %% [markdown]
# Now begins the funny part
# 1. Let's clean the data removing not interesting words
# 2. Let's compute the frequency of use of words
# 3. Let's visualize graphically the computed analysis - Word Cloud

# %%
# 1 cleaning data
def clean_data(content_to_clean):
    print('Before cleaning')
    print(content_to_clean[:600])
    print()
    # simple text normalization: string in lower case
    content_to_clean = content_to_clean.lower()
    # remove punctuations
    cleaned_content = remove_punctuations(content_to_clean)
    # remove stopwords
    #   split the string in a list of words
    cleaned_content_words = cleaned_content.split()
    #   remove stop_words
    cleaned_content_words = remove_stopwords(cleaned_content_words)
    print('After cleaning')
    print(cleaned_content_words[:200])
    print()
    return cleaned_content_words

cleaned_content = clean_data(contents)
#cleaned_content
# Out:
# Before cleaning
# XBB.1.5 makes up more than 40% of cases, the CDC says. While it's more contagious, experts say it seems not to be more dangerous than earlier ones. The true toll of the COVID-19 pandemic on many communities of color is worse than previously known. Behavioral threat assessments are spreading to help stop mass school shootings, but advocates say they are used to remove students who pose no danger. Pope Francis will celebrate the funeral for Benedict on Thursday in St. Peter's Square, according to the Vatican. Historic blizzard leaves at least 50 dead and cancels thousands of flights, China races
#
# After cleaning
# ['xbb15', 'makes', '40', 'cases', 'cdc', 'says', 'contagious', 'experts', 'say', 'seems', 'dangerous', 'earlier', 'ones', 'true', 'toll', 'covid19', 'pandemic', 'many', 'communities', 'color', 'worse', 'previously', 'known', 'behavioral', 'threat', 'assessments', 'spreading', 'help', 'stop', 'mass', 'school', 'shootings', 'advocates', 'say', 'used', 'remove', 'students', 'pose', 'danger', 'pope', 'francis', 'will', 'celebrate', 'funeral', 'benedict', 'thursday', 'st', 'peters', 'square', 'according', 'vatican', 'historic', 'blizzard', 'leaves', 'least', '50', 'dead', 'cancels', 'thousands', 'flights', 'china', 'races', 'vaccinate', 'elderly', 'coronavirus', '5', 'things', 'podcast', 'good', 'news', 'small', 'positive', 'health', 'choices', 'longlasting', 'effects', 'american', 'medical', 'association', 'president', 'jack', 'resneck', 'said', 'public', 'health', 'national', 'defense', 'experts', 'worry', 'next', 'pandemic', 'will', 'come', 'even', 'higher', 'price', 'one', 'nation', 'needs', 'ready', 'us', 'supreme', 'court', 'intervened', 'day', 'title', '42', 'set', 'expire', 'heres', 'look', 'title', '42', 'used', 'impacts', 'border', '2021', 'denmark', 'saw', 'one', 'bank', 'robbery', 'last', 'year', 'none', 'according', 'data', 'finance', 'denmark', 'thats', '222', 'two', 'decades', 'ago', 'predictions', 'forecasts', 'futuregazing', 'selection', 'major', 'international', 'storylines', 'watch', '2023', 'death', 'lucile', 'randon', 'worlds', 'oldest', 'known', 'living', 'person', 'americanborn', 'woman', '115yearold', 'maria', 'branyas', 'morera', 'ban', 'singleuse', 'plastic', 'cutlery', 'utensils', 'england', 'will', 'announced', 'week', 'department', 'environment', 'food', 'rural', 'affairs', 'said', 'according', 'final', 'figures', 'reported', 'cdc', '106699', 'people', 'died', 'result', 'overdose', '92000', 'people', 'died', '2020', 'president', 'joe', 'biden', 'expected', 'meet', 'ecuador', 'president', 'guillermo', 'lasso', 'two', 'will', 'discuss', 'ukrainerussia', 'war']

# %%
# 2 computing word-frequency pairs
def analyze_data(cleaned_content):
    wordcount = {}
    for w in cleaned_content:
        if w in wordcount:
            wordcount[w] += 1
        else:
            wordcount[w] = 1
    return wordcount

wordcount = analyze_data(cleaned_content)
wordcount
# Out:
# {'xbb15': 1,
#  'makes': 1,
#  '40': 1,
#  'cases': 4,
#  'cdc': 2,
#  'says': 1,
#  'contagious': 1,
#  'experts': 2,
#  'say': 2,
#  'seems': 1,
#  'dangerous': 1,
#  'earlier': 1,
#  'ones': 1,
#  'true': 1,
#  'toll': 1,
#  'covid19': 2,
#  'pandemic': 4,
#  'many': 1,
#  'communities': 1,
#  'color': 2,
#  'worse': 1,
#  'previously': 1,
#  'known': 2,
#  'behavioral': 1,
#  'threat': 1,
#  'assessments': 1,
#  'spreading': 1,
#  'help': 1,
#  'stop': 1,
#  'mass': 1,
#  'school': 1,
#  'shootings': 1,
#  'advocates': 1,
#  'used': 2,
#  'remove': 1,
#  'students': 1,
#  'pose': 1,
#  'danger': 1,
#  'pope': 1,
#  'francis': 1,
#  'will': 6,
#  'celebrate': 1,
#  'funeral': 1,
#  'benedict': 1,
#  'thursday': 1,
#  'st': 1,
#  'peters': 1,
#  'square': 1,
#  'according': 3,
#  'vatican': 1,
#  'historic': 1,
#  'blizzard': 1,
#  'leaves': 1,
#  'least': 1,
#  '50': 1,
#  'dead': 1,
#  'cancels': 1,
#  'thousands': 1,
#  'flights': 1,
#  'china': 1,
#  'races': 1,
#  'vaccinate': 1,
#  'elderly': 1,
#  'coronavirus': 1,
#  '5': 1,
#  'things': 1,
#  'podcast': 1,
#  'good': 1,
#  'news': 3,
#  'small': 1,
#  'positive': 1,
#  'health': 2,
#  'choices': 1,
#  'longlasting': 1,
#  'effects': 1,
#  'american': 1,
#  'medical': 1,
#  'association': 1,
#  'president': 4,
#  'jack': 1,
#  'resneck': 1,
#  'said': 2,
#  'public': 1,
#  'national': 1,
#  'defense': 1,
#  'worry': 1,
#  'next': 2,
#  'come': 1,
#  'even': 1,
#  'higher': 1,
#  'price': 1,
#  'one': 2,
#  'nation': 1,
#  'needs': 1,
#  'ready': 1,
#  'us': 3,
#  'supreme': 1,
#  'court': 1,
#  'intervened': 1,
#  'day': 1,
#  'title': 2,
#  '42': 2,
#  'set': 1,
#  'expire': 1,
#  'heres': 1,
#  'look': 1,
#  'impacts': 1,
#  'border': 1,
#  '2021': 1,
#  'denmark': 2,
#  'saw': 1,
#  'bank': 1,
#  'robbery': 1,
#  'last': 2,
#  'year': 2,
#  'none': 1,
#  'data': 1,
#  'finance': 1,
#  'thats': 1,
#  '222': 1,
#  'two': 2,
#  'decades': 1,
#  'ago': 1,
#  'predictions': 1,
#  'forecasts': 1,
#  'futuregazing': 1,
#  'selection': 1,
#  'major': 1,
#  'international': 1,
#  'storylines': 1,
#  'watch': 1,
#  '2023': 1,
#  'death': 1,
#  'lucile': 1,
#  'randon': 1,
#  'worlds': 1,
#  'oldest': 1,
#  'living': 1,
#  'person': 1,
#  'americanborn': 1,
#  'woman': 1,
#  '115yearold': 1,
#  'maria': 1,
#  'branyas': 1,
#  'morera': 1,
#  'ban': 1,
#  'singleuse': 1,
#  'plastic': 1,
#  'cutlery': 1,
#  'utensils': 1,
#  'england': 1,
#  'announced': 1,
#  'week': 1,
#  'department': 1,
#  'environment': 1,
#  'food': 1,
#  'rural': 1,
#  'affairs': 1,
#  'final': 1,
#  'figures': 1,
#  'reported': 1,
#  '106699': 1,
#  'people': 2,
#  'died': 2,
#  'result': 1,
#  'overdose': 1,
#  '92000': 1,
#  '2020': 2,
#  'joe': 1,
#  'biden': 1,
#  'expected': 1,
#  'meet': 1,
#  'ecuador': 1,
#  'guillermo': 1,
#  'lasso': 1,
#  'discuss': 1,
#  'ukrainerussia': 1,
#  'war': 1,
#  'immigration': 1,
#  'apart': 1,
#  'internal': 1,
#  'changes': 1,
#  'makeup': 1,
#  'golden': 1,
#  'globes': 1,
#  'winners': 1,
#  'marked': 1,
#  'change': 1,
#  'several': 1,
#  'creators': 1,
#  'nabbing': 1,
#  'top': 1,
#  'awards': 1,
#  'rules': 1,
#  'give': 1,
#  'power': 1,
#  'individual': 1,
#  'members': 1,
#  'allow': 1,
#  'aggressive': 1,
#  'probes': 1,
#  'administration': 1,
#  'make': 2,
#  'harder': 1,
#  'raise': 1,
#  'spending': 1,
#  'gov': 1,
#  'ron': 1,
#  'desantis': 1,
#  'ask': 1,
#  'legislature': 1,
#  'permanent': 1,
#  'states': 1,
#  'prohibitions': 1,
#  'masks': 1,
#  'schools': 1,
#  'businesses': 1,
#  'vaccine': 1,
#  'requirements': 1,
#  '2017': 1,
#  '275': 1,
#  'nature': 1,
#  'preschools': 1,
#  'operated': 1,
#  'doubled': 1,
#  'theyve': 1,
#  'continued': 1,
#  'grow': 1,
#  'popularity': 1,
#  'amid': 1,
#  'lot': 1,
#  'bad': 1,
#  'staff': 1,
#  'found': 1,
#  'entertaining': 1,
#  'bright': 1,
#  'spots': 1,
#  'gave': 1,
#  'cheer': 1,
#  '2022': 1,
#  'including': 2,
#  'abbott': 1,
#  'elementary': 1,
#  'rrr': 1,
#  'donald': 1,
#  'trump': 2,
#  'brazilian': 1,
#  'jair': 1,
#  'bolsonaro': 1,
#  'contested': 1,
#  'defeat': 1,
#  'violent': 1,
#  'attacks': 1,
#  'government': 1,
#  'buildings': 1,
#  'followed': 1,
#  'panel': 1,
#  'vote': 1,
#  'asking': 1,
#  'feds': 1,
#  'charge': 1,
#  'start': 1,
#  'monday': 1,
#  'caring': 1,
#  'sick': 1,
#  'children': 1,
#  'stressful': 1,
#  'thanks': 1,
#  'shortages': 1,
#  'pain': 1,
#  'relievers': 1,
#  'tylenol': 1,
#  'advil': 1,
#  'prompting': 1,
#  'stores': 1,
#  'limit': 1,
#  'purchases': 1,
#  'tabletop': 1,
#  'exercise': 1,
#  'allowed': 1,
#  'leaders': 1,
#  'think': 1,
#  'respond': 1,
#  'prediction': 1,
#  'coming': 1,
#  'social': 1,
#  'media': 1,
#  'post': 1,
#  'falsely': 1,
#  'claims': 1,
#  'flu': 1,
#  'tracked': 1,
#  'separately': 1}

# %%
# 3 visualizing the analysisis in a Word Cloud
def visualize_data(wordcount):
    wc = WordCloud(width=1200,height=600, background_color='white').generate_from_frequencies(wordcount)
    plt.figure(figsize=(20,10))
    plt.imshow(wc)
    plt.axis("off")
    plt.show()

visualize_data(wordcount)

# %% [markdown]
# # Let's put everything in a function, so that we can run it easily for different sources

# %%
def make_world_cloud(query,source,n_articles=50):
    """
    Download relevant 'n_article' articles that contain 'query' from 'source' newspaper using NewsAPI
    and plot a wordcloud with the most common words in the corpus.
    :param query: 
        Keywords or phrases to search for in the article title and body.
    :param source: 
        the news source or blog you want headlines from
    :param n_articles:
        The number of articles to return (maximum 100)
    """
    # 1.  Download all the articles the online service NewsAPI
    newsapi = NewsApiClient(api_key=my_api_key)
    json_data = newsapi.get_everything(q=query,           # All the articles that contain this word
                                       language='en',
                                       sources=source,      # The newspaper of interest
                                       page_size=n_articles,  # Get 50 articles (by default)
                                       sort_by='relevancy'
                                    )
    
    # 2. Combine the articles into one document (string)
    contents = combine_articles(json_data['articles'])
    
    # 3. cleaning data
    cleaned_content = clean_data(contents)

    # 4. computing word-frequency pairs
    wordcount = analyze_data(cleaned_content)
 
    # 5. Visualizing the analysis in a Word Cloud
    visualize_data(wordcount)

# %%
make_world_cloud('coronavirus','the-verge',100)
# Out:
# Before cleaning
# In 2022, it’s tough to accept the Nintendo Switch’s rough performance. Despite being home to some amazing games, the hardware’s current state can’t do many of them the justice that they deserve. Verily, the health-focused company housed under Google parent Alphabet, is laying off staff and announcing a sweeping reorganization. A new House panel called the Select Subcommittee on the Weaponization of the Federal Government could be the epicenter of the GOP majority’s big tech investigations this Congress. The Verge awards our favorite gadgets from CES 2023,  including the best TV, laptop, car, m
#
# After cleaning
# ['2022', 'it’s', 'tough', 'accept', 'nintendo', 'switch’s', 'rough', 'performance', 'despite', 'home', 'amazing', 'games', 'hardware’s', 'current', 'state', 'can’t', 'many', 'justice', 'deserve', 'verily', 'healthfocused', 'company', 'housed', 'google', 'parent', 'alphabet', 'laying', 'staff', 'announcing', 'sweeping', 'reorganization', 'new', 'house', 'panel', 'called', 'select', 'subcommittee', 'weaponization', 'federal', 'government', 'epicenter', 'gop', 'majority’s', 'big', 'tech', 'investigations', 'congress', 'verge', 'awards', 'favorite', 'gadgets', 'ces', '2023', 'including', 'best', 'tv', 'laptop', 'car', 'monitor', 'smart', 'home', 'tech', 'appearances', 'samsung', 'sony', 'surprises']

# %%
make_world_cloud('coronavirus','bbc-news',100)
# Out:
# Before cleaning
# Prime Minister Narendra Modi held a review meeting amid a surge in cases in China which has put India on alert. China figures show no-one died of Covid on Wednesday - but there is scepticism about the figures. It is the first major death toll released since the country stopped its zero-Covid policy. Donald Trump mourns the death of Lynette Hardaway, one half of commentators Diamond and Silk. The health body says it is worried about the risk to life and again urges Beijing for better data. Controversial Chinese foreign ministry spokesman Zhao Lijian has been moved to another department A surge
#
# After cleaning
# ['prime', 'minister', 'narendra', 'modi', 'held', 'review', 'meeting', 'amid', 'surge', 'cases', 'china', 'put', 'india', 'alert', 'china', 'figures', 'show', 'noone', 'died', 'covid', 'wednesday', 'scepticism', 'figures', 'first', 'major', 'death', 'toll', 'released', 'country', 'stopped', 'zerocovid', 'policy', 'donald', 'trump', 'mourns', 'death', 'lynette', 'hardaway', 'one', 'half', 'commentators', 'diamond', 'silk', 'health', 'body', 'says', 'worried', 'risk', 'life', 'urges', 'beijing', 'better', 'data', 'controversial', 'chinese', 'foreign', 'ministry', 'spokesman', 'zhao', 'lijian', 'moved', 'another', 'department', 'surge', 'covid19', 'cases', 'china', 'creates', 'sense', 'fear', 'among', 'indians', 'fourth', 'wave', 'worlds', 'second', 'largest', 'economy', 'abruptly', 'lifted', 'tough', 'coronavirus', 'restrictions', 'december', 'thousands', 'people', 'coronavirus', 'face', 'yet', 'another', 'christmas', 'smell', 'disorder', 'parosmia', 'brian', 'kilgallon', 'says', 'started', 'making', 'videos', 'son', 'coronavirus', 'lockdown', '£495m', 'loan', 'owed', 'west', 'bromwich', 'albion', 'owner', 'guochuan', 'lai', 'received', 'ahead', '31', 'december', 'deadline', 'international', 'tennis', 'federation', 'end', 'deal', 'exfootballer', 'gerard', 'piques', 'company', 'kosmos', 'organise', 'davis', 'cup', 'less', 'five', 'years', 'two', 'amigos', 'won', 'welsh', 'national', '161', 'chepstow', 'racecourse', 'welsh', 'jockey', 'david', 'prichard', 'giving', 'home', 'fans', 'festive', 'win', 'cheer', 'tensions', 'soared', 'pyongyang', 'tested', 'record', 'number', 'missiles', '2022', 'comes', 'next', 'championship', 'club', 'west', 'brom', 'take', '£20m', 'loan', 'four', 'years', 'us', 'financing', 'group', 'msd', 'holdings', 'new', 'racquet', 'sports', 'stepping', 'tennis', 'shadows', 'pickleball', 'padel', 'boom', 'help', 'celebrities', 'backlash', 'kristalina', 'georgieva', 'said', '2023', 'will', 'tougher', 'last', 'year', 'global', 'economy', 'faces', 'challenges', 'novak']
